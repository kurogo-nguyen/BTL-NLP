# %%
import pandas as pd
import numpy as np
import os
from sklearn.datasets import load_files
import re

# %%
train_path = r"C:\Users\acer\Documents\hoc tap\NLP pj\20news-bydate-train"
test_path = r"C:\Users\acer\Documents\hoc tap\NLP pj\20news-bydate-test"

# %%
folders = sorted(os.listdir(train_path))
folders
# Out:
# ['alt.atheism',
#  'comp.graphics',
#  'comp.os.ms-windows.misc',
#  'comp.sys.ibm.pc.hardware',
#  'comp.sys.mac.hardware',
#  'comp.windows.x',
#  'misc.forsale',
#  'rec.autos',
#  'rec.motorcycles',
#  'rec.sport.baseball',
#  'rec.sport.hockey',
#  'sci.crypt',
#  'sci.electronics',
#  'sci.med',
#  'sci.space',
#  'soc.religion.christian',
#  'talk.politics.guns',
#  'talk.politics.mideast',
#  'talk.politics.misc',
#  'talk.religion.misc']

# %%
train_data = {}
for folder in folders: 
    train_data[folder] = []
    for doc in os.listdir(os.path.join(train_path, folder)):
        with open(os.path.join(train_path, folder, doc), encoding = 'latin-1') as opened_file:
            train_data[folder].append(opened_file.read())
print(len(train_data[folders[0]]))
# Out:
# 480

# %%
test_data = {}
for folder in folders: 
    test_data[folder] = []
    for doc in os.listdir(os.path.join(test_path, folder)):
        with open(os.path.join(test_path, folder, doc), encoding = 'latin-1') as opened_file:
            test_data[folder].append(opened_file.read())
print(len(test_data[folders[0]]))
# Out:
# 319

# %%
import nltk
from string import punctuation 
punctuations=list(punctuation)
stopwords = list(line.strip() for line in open(r"C:\Users\acer\Documents\hoc tap\NLP pj\nltk_data\corpora\stopwords\english",encoding="utf8"))

for item in punctuations:
    stopwords.append(item)

# %%
stopwords
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  '!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  '{',
#  '|',
#  '}',
#  '~']

# %%
new_stopwords = ['subject:','from:', 'date:', 'newsgroups:', 'message-id:', 'lines:', 'path:', 'organization:', 
            'would', 'writes:', 'references:', 'article', 'sender:', 'nntp-posting-host:', 'people', 
            'university', 'think', 'xref:', 'cantaloupe.srv.cs.cmu.edu', 'could', 'distribution:', 'first', 
            'anyone','world', 'really', 'since', 'right', 'believe', 'still']
stopwords.append(item)

# %%
print(stopwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", '!', '"', '#', '$', '%', '&', "'", '(', ')', '*', '+', ',', '-', '.', '/', ':', ';', '<', '=', '>', '?', '@', '[', '\\', ']', '^', '_', '`', '{', '|', '}', '~', '~']

# %%
Y_train = []
for i in range(len(train_data)):
    for doc in train_data[folders[i]]:
        Y_train.append(folders[i])

Y_train = np.array(Y_train)
print(len(Y_train))
# Out:
# 11314

# %%
Y_test = []
for i in range(len(test_data)):
    for doc in test_data[folders[i]]:
        Y_test.append(folders[i])

Y_test = np.array(Y_test)
print(len(Y_test))
# Out:
# 7532

# %%
from nltk.tokenize import word_tokenize

# %%
X_train = []
for folder in train_data:
    for doc in train_data[folder]:
        tokenized_doc = word_tokenize(doc)
        newdoc = []
        for word in tokenized_doc:
             if len(word) < 21 and len(word) > 1:
                if any(c.isdigit() for c in word): #or c == "_"
                    newdoc.append('0')
                    continue
                if word.lower() not in stopwords:
                    newword = re.sub(r'[^A-Za-z]+', '', word.lower())
                    newdoc.append(newword.lower())
        X_train.append(newdoc)
X_train[0]
# Out:
# ['mathew',
#  'mathew',
#  'mantiscouk',
#  'subject',
#  'altatheism',
#  'faq',
#  'atheist',
#  'resources',
#  'summary',
#  'books',
#  'addresses',
#  'music',
#  '',
#  'anything',
#  'related',
#  'atheism',
#  'keywords',
#  'faq',
#  'atheism',
#  'books',
#  'music',
#  'fiction',
#  'addresses',
#  'contacts',
#  'expires',
#  'thu',
#  '0',
#  'apr',
#  '0',
#  '0',
#  'gmt',
#  'distribution',
#  'world',
#  'organization',
#  'mantis',
#  'consultants',
#  'cambridge',
#  'uk',
#  'supersedes',
#  '0',
#  'mantiscouk',
#  'lines',
#  '0',
#  'archivename',
#  'atheismresources',
#  'resources',
#  'lastmodified',
#  '0',
#  'december',
#  '0',
#  'version',
#  '0',
#  'atheist',
#  'resources',
#  'addresses',
#  'atheist',
#  'organizations',
#  'usa',
#  'freedom',
#  'religion',
#  'foundation',
#  'darwin',
#  'fish',
#  'bumper',
#  'stickers',
#  'assorted',
#  'atheist',
#  'paraphernalia',
#  'available',
#  'freedom',
#  'religion',
#  'foundation',
#  'us',
#  'write',
#  'ffrf',
#  'po',
#  'box',
#  '0',
#  'madison',
#  'wi',
#  '0',
#  'telephone',
#  '0',
#  '0',
#  'evolution',
#  'designs',
#  'evolution',
#  'designs',
#  'sell',
#  '',
#  'darwin',
#  'fish',
#  '',
#  's',
#  'fish',
#  'symbol',
#  'like',
#  'ones',
#  'christians',
#  'stick',
#  'cars',
#  'feet',
#  'word',
#  '',
#  'darwin',
#  '',
#  'written',
#  'inside',
#  'deluxe',
#  'moulded',
#  '0',
#  'plastic',
#  'fish',
#  '0',
#  'postpaid',
#  'us',
#  'write',
#  'evolution',
#  'designs',
#  '0',
#  'laurel',
#  'canyon',
#  'north',
#  'hollywood',
#  'ca',
#  '0',
#  'people',
#  'san',
#  'francisco',
#  'bay',
#  'area',
#  'get',
#  'darwin',
#  'fish',
#  'lynn',
#  'gold',
#  '',
#  'try',
#  'mailing',
#  'figmo',
#  'netcomcom',
#  'net',
#  'people',
#  'go',
#  'lynn',
#  'directly',
#  'price',
#  '0',
#  'per',
#  'fish',
#  'american',
#  'atheist',
#  'press',
#  'aap',
#  'publish',
#  'various',
#  'atheist',
#  'books',
#  '',
#  'critiques',
#  'bible',
#  'lists',
#  'biblical',
#  'contradictions',
#  'one',
#  'book',
#  '',
#  'bible',
#  'handbook',
#  '',
#  'wp',
#  'ball',
#  'gw',
#  'foote',
#  'american',
#  'atheist',
#  'press',
#  '0',
#  'pp',
#  'isbn',
#  '0',
#  '0',
#  'edition',
#  '0',
#  'bible',
#  'contradictions',
#  'absurdities',
#  'atrocities',
#  'immoralities',
#  '',
#  'contains',
#  'ball',
#  'foote',
#  '',
#  'bible',
#  'contradicts',
#  '',
#  'aap',
#  'based',
#  'king',
#  'james',
#  'version',
#  'bible',
#  'write',
#  'american',
#  'atheist',
#  'press',
#  'po',
#  'box',
#  '0',
#  'austin',
#  'tx',
#  '0',
#  '0',
#  'cameron',
#  'road',
#  'austin',
#  'tx',
#  '0',
#  'telephone',
#  '0',
#  '0',
#  'fax',
#  '0',
#  '0',
#  'prometheus',
#  'books',
#  'sell',
#  'books',
#  'including',
#  'haught',
#  's',
#  '',
#  'holy',
#  'horrors',
#  '',
#  'see',
#  'write',
#  '0',
#  'east',
#  'amherst',
#  'street',
#  'buffalo',
#  'new',
#  'york',
#  '0',
#  'telephone',
#  '0',
#  '0',
#  'alternate',
#  'address',
#  'may',
#  'newer',
#  'older',
#  'prometheus',
#  'books',
#  '0',
#  'glenn',
#  'drive',
#  'buffalo',
#  'ny',
#  '0',
#  'africanamericans',
#  'humanism',
#  'organization',
#  'promoting',
#  'black',
#  'secular',
#  'humanism',
#  'uncovering',
#  'history',
#  'black',
#  'freethought',
#  'publish',
#  'quarterly',
#  'newsletter',
#  'aah',
#  'examiner',
#  'write',
#  'norm',
#  'r',
#  'allen',
#  'jr',
#  'african',
#  'americans',
#  'humanism',
#  'po',
#  'box',
#  '0',
#  'buffalo',
#  'ny',
#  '0',
#  'united',
#  'kingdom',
#  'rationalist',
#  'press',
#  'association',
#  'national',
#  'secular',
#  'society',
#  '0',
#  'islington',
#  'high',
#  'street',
#  '0',
#  'holloway',
#  'road',
#  'london',
#  '0',
#  '0',
#  'london',
#  '0',
#  '0',
#  '0',
#  '0',
#  '0',
#  '0',
#  '0',
#  '0',
#  'british',
#  'humanist',
#  'association',
#  'south',
#  'place',
#  'ethical',
#  'society',
#  '0',
#  'lamb',
#  's',
#  'conduit',
#  'passage',
#  'conway',
#  'hall',
#  'london',
#  '0',
#  '0',
#  'red',
#  'lion',
#  'square',
#  '0',
#  '0',
#  '0',
#  'london',
#  '0',
#  '0',
#  'fax',
#  '0',
#  '0',
#  '0',
#  '0',
#  '0',
#  '0',
#  'national',
#  'secular',
#  'society',
#  'publish',
#  '',
#  'freethinker',
#  '',
#  'monthly',
#  'magazine',
#  'founded',
#  '0',
#  'germany',
#  'ibka',
#  'ev',
#  'internationaler',
#  'bund',
#  'der',
#  'konfessionslosen',
#  'und',
#  'atheisten',
#  'postfach',
#  '0',
#  '0',
#  'berlin',
#  '0',
#  'germany',
#  'ibka',
#  'publish',
#  'journal',
#  'miz',
#  'materialien',
#  'und',
#  'informationen',
#  'zur',
#  'zeit',
#  'politisches',
#  'journal',
#  'der',
#  'konfessionslosesn',
#  'und',
#  'atheisten',
#  'hrsg',
#  'ibka',
#  'ev',
#  'mizvertrieb',
#  'postfach',
#  '0',
#  '0',
#  'berlin',
#  '0',
#  'germany',
#  'atheist',
#  'books',
#  'write',
#  'ibdk',
#  'internationaler',
#  '',
#  'ucherdienst',
#  'der',
#  'konfessionslosen',
#  'postfach',
#  '0',
#  '0',
#  'hannover',
#  'germany',
#  'telephone',
#  '0',
#  'books',
#  '',
#  'fiction',
#  'thomas',
#  'm',
#  'disch',
#  '',
#  'santa',
#  'claus',
#  'compromise',
#  '',
#  'short',
#  'story',
#  'ultimate',
#  'proof',
#  'santa',
#  'exists',
#  'characters',
#  'events',
#  'fictitious',
#  'similarity',
#  'living',
#  'dead',
#  'gods',
#  '',
#  'uh',
#  'well',
#  '',
#  'walter',
#  'm',
#  'miller',
#  'jr',
#  '',
#  'canticle',
#  'leibowitz',
#  '',
#  'one',
#  'gem',
#  'post',
#  'atomic',
#  'doomsday',
#  'novel',
#  'monks',
#  'spent',
#  'lives',
#  'copying',
#  'blueprints',
#  '',
#  'saint',
#  'leibowitz',
#  '',
#  'filling',
#  'sheets',
#  'paper',
#  'ink',
#  'leaving',
#  'white',
#  'lines',
#  'letters',
#  'edgar',
#  'pangborn',
#  '',
#  'davy',
#  '',
#  'post',
#  'atomic',
#  'doomsday',
#  'novel',
#  'set',
#  'clerical',
#  'states',
#  'church',
#  'example',
#  'forbids',
#  'anyone',
#  '',
#  'produce',
#  'describe',
#  'use',
#  'substance',
#  'containing',
#  '',
#  'atoms',
#  '',
#  'philip',
#  'k',
#  'dick',
#  'philip',
#  'k',
#  'dick',
#  'dick',
#  'wrote',
#  'many',
#  'philosophical',
#  'thoughtprovoking',
#  'short',
#  'stories',
#  'novels',
#  'stories',
#  'bizarre',
#  'times',
#  'approachable',
#  'wrote',
#  'mainly',
#  'sf',
#  'wrote',
#  'people',
#  'truth',
#  'religion',
#  'rather',
#  'technology',
#  'although',
#  'often',
#  'believed',
#  'met',
#  'sort',
#  'god',
#  'remained',
#  'sceptical',
#  'amongst',
#  'novels',
#  'following',
#  'relevance',
#  '',
#  'galactic',
#  'pothealer',
#  '',
#  'fallible',
#  'alien',
#  'deity',
#  'summons',
#  'group',
#  'earth',
#  'craftsmen',
#  'women',
#  'remote',
#  'planet',
#  'raise',
#  'giant',
#  'cathedral',
#  'beneath',
#  'oceans',
#  'deity',
#  'begins',
#  'demand',
#  'faith',
#  'earthers',
#  'pothealer',
#  'joe',
#  'fernwright',
#  'unable',
#  'comply',
#  'polished',
#  'ironic',
#  'amusing',
#  'novel',
#  '',
#  'maze',
#  'death',
#  '',
#  'noteworthy',
#  'description',
#  'technologybased',
#  'religion',
#  '',
#  'valis',
#  '',
#  'schizophrenic',
#  'hero',
#  'searches',
#  'hidden',
#  'mysteries',
#  'gnostic',
#  'christianity',
#  'reality',
#  'fired',
#  'brain',
#  'pink',
#  'laser',
#  'beam',
#  'unknown',
#  'possibly',
#  'divine',
#  'origin',
#  'accompanied',
#  'dogmatic',
#  'dismissively',
#  'atheist',
#  'friend',
#  'assorted',
#  'odd',
#  'characters',
#  '',
#  'divine',
#  'invasion',
#  '',
#  'god',
#  'invades',
#  'earth',
#  'making',
#  'young',
#  'woman',
#  'pregnant',
#  'returns',
#  'another',
#  'star',
#  'system',
#  'unfortunately',
#  'terminally',
#  'ill',
#  'must',
#  'assisted',
#  'dead',
#  'man',
#  'whose',
#  'brain',
#  'wired',
#  '0',
#  'easy',
#  'listening',
#  'music',
#  'margaret',
#  'atwood',
#  '',
#  'handmaid',
#  's',
#  'tale',
#  '',
#  'story',
#  'based',
#  'premise',
#  'us',
#  'congress',
#  'mysteriously',
#  'assassinated',
#  'fundamentalists',
#  'quickly',
#  'take',
#  'charge',
#  'nation',
#  'set',
#  '',
#  'right',
#  '',
#  'book',
#  'diary',
#  'woman',
#  's',
#  'life',
#  'tries',
#  'live',
#  'new',
#  'christian',
#  'theocracy',
#  'women',
#  's',
#  'right',
#  'property',
#  'revoked',
#  'bank',
#  'accounts',
#  'closed',
#  'sinful',
#  'luxuries',
#  'outlawed',
#  'radio',
#  'used',
#  'readings',
#  'bible',
#  'crimes',
#  'punished',
#  'retroactively',
#  'doctors',
#  'performed',
#  'legal',
#  'abortions',
#  '',
#  'old',
#  'world',
#  '',
#  'hunted',
#  'hanged',
#  'atwood',
#  's',
#  'writing',
#  'style',
#  'difficult',
#  'get',
#  'used',
#  'first',
#  'tale',
#  'grows',
#  'chilling',
#  'goes',
#  'various',
#  'authors',
#  '',
#  'bible',
#  '',
#  'somewhat',
#  'dull',
#  'rambling',
#  'work',
#  'often',
#  'criticized',
#  'however',
#  'probably',
#  'worth',
#  'reading',
#  'll',
#  'know',
#  'fuss',
#  'exists',
#  'many',
#  'different',
#  'versions',
#  'make',
#  'sure',
#  'get',
#  'one',
#  'true',
#  'version',
#  'books',
#  '',
#  'nonfiction',
#  'peter',
#  'de',
#  'rosa',
#  '',
#  'vicars',
#  'christ',
#  '',
#  'bantam',
#  'press',
#  '0',
#  'although',
#  'de',
#  'rosa',
#  'seems',
#  'christian',
#  'even',
#  'catholic',
#  'enlighting',
#  'history',
#  'papal',
#  'immoralities',
#  'adulteries',
#  'fallacies',
#  'etc',
#  'german',
#  'translation',
#  '',
#  'gottes',
#  'erste',
#  'diener',
#  'die',
#  'dunkle',
#  'seite',
#  'des',
#  'papsttums',
#  '',
#  'droemerknaur',
#  '0',
#  'michael',
#  'martin',
#  '',
#  'atheism',
#  'philosophical',
#  'justification',
#  '',
#  'temple',
#  'university',
#  'press',
#  'philadelphia',
#  'usa',
#  'detailed',
#  'scholarly',
#  'justification',
#  'atheism',
#  'contains',
#  'outstanding',
#  'appendix',
#  'defining',
#  'terminology',
#  'usage',
#  'necessarily',
#  'tendentious',
#  'area',
#  'argues',
#  '',
#  'negative',
#  'atheism',
#  '',
#  'ie',
#  '',
#  'nonbelief',
#  'existence',
#  'god',
#  '',
#  'also',
#  '',
#  'positive',
#  'atheism',
#  '',
#  '',
#  'belief',
#  'nonexistence',
#  'god',
#  '',
#  'includes',
#  'great',
#  'refutations',
#  'challenging',
#  'arguments',
#  'god',
#  'particular',
#  'attention',
#  'paid',
#  'refuting',
#  'contempory',
#  'theists',
#  'platinga',
#  'swinburne',
#  '0',
#  'pages',
#  'isbn',
#  '0',
#  'hardcover',
#  'paperback',
#  'also',
#  'available',
#  '',
#  'case',
#  'christianity',
#  '',
#  'temple',
#  'university',
#  'press',
#  'comprehensive',
#  'critique',
#  'christianity',
#  'considers',
#  'best',
#  'contemporary',
#  'defences',
#  'christianity',
#  'ultimately',
#  'demonstrates',
#  'unsupportable',
#  'andor',
#  'incoherent',
#  '0',
#  'pages',
#  'isbn',
#  '0',
#  'james',
#  'turner',
#  '',
#  'without',
#  'god',
#  'without',
#  'creed',
#  '',
#  'johns',
#  'hopkins',
#  'university',
#  'press',
#  'baltimore',
#  'md',
#  'usa',
#  'subtitled',
#  '',
#  'origins',
#  'unbelief',
#  'america',
#  '',
#  'examines',
#  'way',
#  'unbelief',
#  'whether',
#  'agnostic',
#  'atheistic',
#  'became',
#  'mainstream',
#  'alternative',
#  'worldview',
#  'focusses',
#  'period',
#  '0',
#  'considering',
#  'france',
#  'britain',
#  'emphasis',
#  'american',
#  'particularly',
#  'new',
#  'england',
#  'developments',
#  '',
#  'neither',
#  'religious',
#  'history',
#  'secularization',
#  'atheism',
#  'without',
#  'god',
#  'without',
#  'creed',
#  'rather',
#  'intellectual',
#  'history',
#  'fate',
#  'single',
#  'idea',
#  'belief',
#  'god',
#  'exists',
#  '',
#  '0',
#  'pages',
#  'isbn',
#  'hardcover',
#  '0',
#  'paper',
#  '0',
#  'george',
#  'seldes',
#  'editor',
#  '',
#  'great',
#  'thoughts',
#  '',
#  'ballantine',
#  'books',
#  'new',
#  'york',
#  'usa',
#  '',
#  'dictionary',
#  'quotations',
#  '',
#  'different',
#  'kind',
#  'concentrating',
#  'statements',
#  'writings',
#  'explicitly',
#  'implicitly',
#  'present',
#  'person',
#  's',
#  'philosophy',
#  'worldview',
#  'includes',
#  'obscure',
#  'often',
#  'suppressed',
#  'opinions',
#  'many',
#  'people',
#  'popular',
#  'observations',
#  'traces',
#  'way',
#  'various',
#  'people',
#  'expressed',
#  'twisted',
#  'idea',
#  'centuries',
#  'quite',
#  'number',
#  'quotations',
#  'derived',
#  'cardiff',
#  's',
#  '',
#  'great',
#  'men',
#  'think',
#  'religion',
#  ...]

# %%
X_test = []
for folder in test_data:
    for doc in test_data[folder]:
        tokenized_doc = word_tokenize(doc)
        newdoc = []
        for word in tokenized_doc:
             if len(word) < 21 and len(word) > 1:
                if any(c.isdigit() for c in word): #or c == "_" 
                    newdoc.append('0')
                    continue
                if word.lower() not in stopwords:
                    newword = re.sub(r'[^A-Za-z]+', '', word.lower())
                    newdoc.append(newword.lower())
        X_test.append(newdoc)
X_test[0]
# Out:
# ['decay',
#  'cbnewsjcbattcom',
#  'deankaflowitz',
#  'subject',
#  'bible',
#  'quiz',
#  'answers',
#  'organization',
#  'distribution',
#  'na',
#  'lines',
#  '0',
#  'article',
#  '0',
#  'saturnwwcedu',
#  'healta',
#  'saturnwwcedu',
#  'tammy',
#  'healy',
#  'writes',
#  '0',
#  'cheribums',
#  'ark',
#  'covenant',
#  'god',
#  'said',
#  'make',
#  'graven',
#  'image',
#  'refering',
#  'idols',
#  'created',
#  'worshipped',
#  'ark',
#  'covenant',
#  'nt',
#  'wrodhipped',
#  'high',
#  'priest',
#  'could',
#  'enter',
#  'holy',
#  'holies',
#  'kept',
#  'year',
#  'day',
#  'atonement',
#  'familiar',
#  'knowledgeable',
#  'original',
#  'language',
#  'believe',
#  'word',
#  '',
#  'idol',
#  '',
#  'translator',
#  'would',
#  'used',
#  'word',
#  '',
#  'idol',
#  '',
#  'instead',
#  '',
#  'graven',
#  'image',
#  '',
#  'original',
#  'said',
#  '',
#  'idol',
#  '',
#  'think',
#  're',
#  'wrong',
#  'could',
#  'suggesting',
#  'way',
#  'determine',
#  'whether',
#  'interpretation',
#  'offer',
#  'correct',
#  'dean',
#  'kaflowitz']

# %%
X_train_combine = []
for doc in X_train:
    X_train_combine.append(' '.join(doc))

# %%
X_train_combine[0]
# Out:
# 'mathew mathew mantiscouk subject altatheism faq atheist resources summary books addresses music  anything related atheism keywords faq atheism books music fiction addresses contacts expires thu 0 apr 0 0 gmt distribution world organization mantis consultants cambridge uk supersedes 0 mantiscouk lines 0 archivename atheismresources resources lastmodified 0 december 0 version 0 atheist resources addresses atheist organizations usa freedom religion foundation darwin fish bumper stickers assorted atheist paraphernalia available freedom religion foundation us write ffrf po box 0 madison wi 0 telephone 0 0 evolution designs evolution designs sell  darwin fish  s fish symbol like ones christians stick cars feet word  darwin  written inside deluxe moulded 0 plastic fish 0 postpaid us write evolution designs 0 laurel canyon north hollywood ca 0 people san francisco bay area get darwin fish lynn gold  try mailing figmo netcomcom net people go lynn directly price 0 per fish american atheist press aap publish various atheist books  critiques bible lists biblical contradictions one book  bible handbook  wp ball gw foote american atheist press 0 pp isbn 0 0 edition 0 bible contradictions absurdities atrocities immoralities  contains ball foote  bible contradicts  aap based king james version bible write american atheist press po box 0 austin tx 0 0 cameron road austin tx 0 telephone 0 0 fax 0 0 prometheus books sell books including haught s  holy horrors  see write 0 east amherst street buffalo new york 0 telephone 0 0 alternate address may newer older prometheus books 0 glenn drive buffalo ny 0 africanamericans humanism organization promoting black secular humanism uncovering history black freethought publish quarterly newsletter aah examiner write norm r allen jr african americans humanism po box 0 buffalo ny 0 united kingdom rationalist press association national secular society 0 islington high street 0 holloway road london 0 0 london 0 0 0 0 0 0 0 0 british humanist association south place ethical society 0 lamb s conduit passage conway hall london 0 0 red lion square 0 0 0 london 0 0 fax 0 0 0 0 0 0 national secular society publish  freethinker  monthly magazine founded 0 germany ibka ev internationaler bund der konfessionslosen und atheisten postfach 0 0 berlin 0 germany ibka publish journal miz materialien und informationen zur zeit politisches journal der konfessionslosesn und atheisten hrsg ibka ev mizvertrieb postfach 0 0 berlin 0 germany atheist books write ibdk internationaler  ucherdienst der konfessionslosen postfach 0 0 hannover germany telephone 0 books  fiction thomas m disch  santa claus compromise  short story ultimate proof santa exists characters events fictitious similarity living dead gods  uh well  walter m miller jr  canticle leibowitz  one gem post atomic doomsday novel monks spent lives copying blueprints  saint leibowitz  filling sheets paper ink leaving white lines letters edgar pangborn  davy  post atomic doomsday novel set clerical states church example forbids anyone  produce describe use substance containing  atoms  philip k dick philip k dick dick wrote many philosophical thoughtprovoking short stories novels stories bizarre times approachable wrote mainly sf wrote people truth religion rather technology although often believed met sort god remained sceptical amongst novels following relevance  galactic pothealer  fallible alien deity summons group earth craftsmen women remote planet raise giant cathedral beneath oceans deity begins demand faith earthers pothealer joe fernwright unable comply polished ironic amusing novel  maze death  noteworthy description technologybased religion  valis  schizophrenic hero searches hidden mysteries gnostic christianity reality fired brain pink laser beam unknown possibly divine origin accompanied dogmatic dismissively atheist friend assorted odd characters  divine invasion  god invades earth making young woman pregnant returns another star system unfortunately terminall ...

# %%
X_test_combine = []
for doc in X_test:
    X_test_combine.append(' '.join(doc))

# %%
X_train = X_train_combine
print(len(X_train))
# Out:
# 11314

# %%
print(len(Y_train))
# Out:
# 11314

# %%
X_test = X_test_combine
print(len(X_test))
# Out:
# 7532

# %%
print(len(Y_test))
# Out:
# 7532

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer()

# %%
from sklearn.pipeline import Pipeline

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
pclf = Pipeline([
    ('cvec',vectorizer),
    ('nbclf', MultinomialNB())
])
pclf.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('cvec', CountVectorizer()), ('nbclf', MultinomialNB())])

# %%
print(vectorizer.get_feature_names())
# Out:
# ['aa', 'aaa', 'aaaa', 'aaaaaaaaaaaa', 'aaaaagggghhhh', 'aaaarrgghhhh', 'aaah', 'aaahh', 'aaahhhh', 'aaai', 'aaaimit', 'aaamajors', 'aaauoregonedu', 'aab', 'aacadslbcom', 'aacc', 'aachen', 'aacvkc', 'aad', 'aadams', 'aaf', 'aah', 'aalaci', 'aalborg', 'aaldoubo', 'aalternate', 'aam', 'aamazing', 'aamir', 'aams', 'aan', 'aanbieden', 'aanerud', 'aangeboden', 'aangegeven', 'aangezien', 'aanp', 'aantal', 'aantalsnijpunten', 'aao', 'aaoeppaaogovau', 'aap', 'aaplayexe', 'aardvark', 'aargh', 'aarghhhh', 'aarhus', 'aario', 'aarm', 'aaron', 'aaronbratcher', 'aaronc', 'aaronson', 'aarp', 'aarseth', 'aarskog', 'aartolsen', 'aas', 'aasaiaa', 'aasked', 'aassists', 'aatchoo', 'aav', 'aaverage', 'aavj', 'aavso', 'aax', 'aazaadee', 'ab', 'ababspalestinians', 'abacus', 'abacusbatesedu', 'abacusconcordiaca', 'abad', 'abaihm', 'abandon', 'abandond', 'abandonded', 'abandoned', 'abandoning', 'abandonment', 'abandons', 'abarden', 'abate', 'abatement', 'abates', 'abaum', 'abba', 'abbasids', 'abberant', 'abberation', 'abberley', 'abbey', 'abbie', 'abbot', 'abbott', 'abboud', 'abbrev', 'abbreviated', 'abbreviation', 'abbreviations', 'abbshansede', 'abc', 'abcd', 'abcdef', 'abcdhoughtonmius', 'abcom', 'abcpv', 'abd', 'abdel', 'abdelrahem', 'abdi', 'abdication', 'abdkw', 'abdo', 'abdomen', 'abdomens', 'abdominal', 'abduct', 'abducted', 'abduction', 'abdul', 'abdulcebbar', 'abdulhamid', 'abdullah', 'abdullahad', 'abe', 'abea', 'abeel', 'abeit', 'abekas', 'abel', 'aben', 'abensberg', 'abeoz', 'aber', 'aberacuk', 'aberdeen', 'aberkvam', 'abernathy', 'aberrant', 'aberration', 'aberrations', 'aberystwyth', 'abetter', 'abeyer', 'abfb', 'abfdefghiijklmmnohpp', 'abg', 'abgarovich', 'abhin', 'abhkcbdz', 'abhor', 'abhorent', 'abhorred', 'abhorrences', 'abhorrent', 'abhout', 'abide', 'abides', 'abideth', 'abiding', 'abig', 'abigail', 'abild', 'abildskov', 'abilene', 'abilities', 'ability', 'abiliy', 'abingdon', 'abingdonsuncom', 'abington', 'abiogenesis', 'abkect', 'abkhazia', 'ablaze', 'ablazing', 'able', 'ablebodied', 'ablility', 'ably', 'abnamro', 'abner', 'abnormal', 'abnormalities', 'abnormally', 'abnt', 'abo', 'aboard', 'aboce', 'abode', 'abodes', 'abofi', 'aboid', 'abolish', 'abolished', 'abolishing', 'abolishment', 'abolition', 'abolitionist', 'abolitionists', 'abomb', 'abombs', 'abominable', 'abomination', 'abominations', 'aboove', 'abord', 'aboritionists', 'abort', 'aborted', 'abortion', 'abortionlaw', 'abortions', 'aborts', 'abott', 'abotu', 'abou', 'abound', 'abounded', 'abounds', 'about', 'abouts', 'abovax', 'above', 'abovementioned', 'abovequoted', 'abovew', 'aboyko', 'abp', 'abph', 'abpsoft', 'abput', 'abqi', 'abraam', 'abraham', 'abrahamic', 'abram', 'abramyan', 'abrash', 'abrasions', 'abrasives', 'abravo', 'abraxis', 'abreast', 'abridge', 'abridged', 'abridgement', 'abridgements', 'abridging', 'abridgment', 'abroad', 'abrogate', 'abrogation', 'abrupt', 'abruptly', 'abs', 'absair', 'abscence', 'abscess', 'absence', 'absences', 'absense', 'absent', 'absentee', 'absentmindedly', 'absequipped', 'absgh', 'absitinence', 'absli', 'absolabsolcom', 'absolut', 'absolute', 'absolutely', 'absoluteprimodick', 'absolutes', 'absolutey', 'absolutism', 'absolutist', 'absolutists', 'absolve', 'absolved', 'absolving', 'absood', 'absorb', 'absorbed', 'absorber', 'absorbers', 'absorbing', 'absorbs', 'absorbtion', 'absorption', 'absorptionlike', 'absoultly', 'abstact', 'abstacted', 'abstain', 'abstaining', 'abstinence', 'abstinenceeducation', 'abstinencerelated', 'abstinencne', 'abstract', 'abstractdescription', 'abstraction', 'abstractions', 'abstracts', 'abstractsoftcom', 'absurb', 'absurd', 'absurdities', 'absurdity', 'absurdium', 'absurdly', 'absurdum', 'absx', 'absy', 'abt', 'abu', 'abuabed', 'abue', 'abuealyan', 'abuhajras', 'abujamea', 'abulfaz', 'abumostafa', 'abundance', 'abundances', 'abundant', 'abundantly', 'abuot', 'abus', 'abusalim', 'abuse', 'abused', 'abuser', 'abusers', 'abuses', 'abusing', 'abusive', 'abutaha', 'abutment', 'abuzabal', 'abve', 'abvious', ...

# %%
Y_pred = pclf.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(Y_pred,Y_test))
# Out:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.77      0.79      0.78       312
#            comp.graphics       0.78      0.67      0.72       453
#  comp.os.ms-windows.misc       0.07      0.88      0.13        32
# comp.sys.ibm.pc.hardware       0.80      0.55      0.65       573
#    comp.sys.mac.hardware       0.83      0.80      0.82       400
#           comp.windows.x       0.82      0.72      0.77       449
#             misc.forsale       0.73      0.91      0.81       312
#                rec.autos       0.93      0.89      0.91       415
#          rec.motorcycles       0.94      0.96      0.95       392
#       rec.sport.baseball       0.93      0.97      0.95       381
#         rec.sport.hockey       0.98      0.94      0.96       416
#                sci.crypt       0.95      0.76      0.84       500
#          sci.electronics       0.72      0.81      0.76       348
#                  sci.med       0.87      0.92      0.90       376
#                sci.space       0.92      0.88      0.90       408
#   soc.religion.christian       0.95      0.76      0.85       497
#       talk.politics.guns       0.93      0.69      0.80       488
#    talk.politics.mideast       0.94      0.93      0.94       379
#       talk.politics.misc       0.62      0.68      0.65       281
#       talk.religion.misc       0.42      0.88      0.57       120
#
#                 accuracy                           0.80      7532
#                macro avg       0.80      0.82      0.78      7532
#             weighted avg       0.86      0.80      0.82      7532

# %%
from sklearn.linear_model import SGDClassifier

# %%
pclf = Pipeline([
    ('cvec',vectorizer),
    ('SGD', SGDClassifier())
])
pclf.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('cvec', CountVectorizer()), ('SGD', SGDClassifier())])

# %%
Y_pred = pclf.predict(X_test)

# %%
print(classification_report(Y_pred,Y_test))
# Out:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.67      0.75      0.71       283
#            comp.graphics       0.57      0.62      0.59       360
#  comp.os.ms-windows.misc       0.61      0.60      0.61       404
# comp.sys.ibm.pc.hardware       0.67      0.61      0.64       428
#    comp.sys.mac.hardware       0.74      0.75      0.75       379
#           comp.windows.x       0.67      0.70      0.68       379
#             misc.forsale       0.82      0.73      0.77       439
#                rec.autos       0.83      0.80      0.82       408
#          rec.motorcycles       0.91      0.87      0.89       418
#       rec.sport.baseball       0.86      0.75      0.80       453
#         rec.sport.hockey       0.92      0.81      0.86       451
#                sci.crypt       0.82      0.84      0.83       384
#          sci.electronics       0.56      0.68      0.61       324
#                  sci.med       0.72      0.82      0.77       348
#                sci.space       0.84      0.75      0.79       436
#   soc.religion.christian       0.85      0.76      0.80       444
#       talk.politics.guns       0.79      0.64      0.71       452
#    talk.politics.mideast       0.76      0.94      0.84       303
#       talk.politics.misc       0.49      0.76      0.59       201
#       talk.religion.misc       0.54      0.57      0.55       238
#
#                 accuracy                           0.74      7532
#                macro avg       0.73      0.74      0.73      7532
#             weighted avg       0.75      0.74      0.74      7532

# %%
# Out:
# ['hi', 'i', 'am', 'bim', 'deptrai', 'hello', 'how', '', '', '', '', 'are', '', 'you', 'deptrai']

# %%
# Out:
# ['am', 'are', 'bim', 'deptrai', 'hello', 'hi', 'how', 'you']
