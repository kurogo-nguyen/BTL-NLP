# %%
import pandas as pd
import numpy as np
import os
from sklearn.datasets import load_files

# %%
train_path = r"C:\Users\acer\Documents\hoc tap\NLP pj\20news-bydate-train"
test_path = r"C:\Users\acer\Documents\hoc tap\NLP pj\20news-bydate-test"

# %%
folders = sorted(os.listdir(train_path))
folders
# Out:
# ['alt.atheism',
#  'comp.graphics',
#  'comp.os.ms-windows.misc',
#  'comp.sys.ibm.pc.hardware',
#  'comp.sys.mac.hardware',
#  'comp.windows.x',
#  'misc.forsale',
#  'rec.autos',
#  'rec.motorcycles',
#  'rec.sport.baseball',
#  'rec.sport.hockey',
#  'sci.crypt',
#  'sci.electronics',
#  'sci.med',
#  'sci.space',
#  'soc.religion.christian',
#  'talk.politics.guns',
#  'talk.politics.mideast',
#  'talk.politics.misc',
#  'talk.religion.misc']

# %%
data = {}
for folder in folders: 
    data[folder] = []
    for doc in os.listdir(os.path.join(train_path, folder)):
        with open(os.path.join(train_path, folder, doc), encoding = 'latin-1') as opened_file:
            data[folder].append(opened_file.read())
print(len(data[folders[0]]))
# Out:
# 480

# %%
import nltk
from string import punctuation 
punctuations=list(punctuation)
stopwords = list(line.strip() for line in open(r"C:\Users\acer\Documents\hoc tap\NLP pj\nltk_data\corpora\stopwords\english",encoding="utf8"))

for item in punctuations:
    stopwords.append(item)

# %%
new_stopwords = ['subject:','from:', 'date:', 'newsgroups:', 'message-id:', 'lines:', 'path:', 'organization:', 
            'would', 'writes:', 'references:', 'article', 'sender:', 'nntp-posting-host:', 'people', 
            'university', 'think', 'xref:', 'cantaloupe.srv.cs.cmu.edu', 'could', 'distribution:', 'first', 
            'anyone','world', 'really', 'since', 'right', 'believe', 'still','__', '___', '____', '_____', '______', '_______', '________', '_________', '__________', '___________', '____________', '_____________', '______________', '_______________', '________________', '_________________', '__________________', '___________________', '____________________', '_____________________', '______________________', '_______________________', '________________________', '__________________________', '___________________________', '____________________________', '_____________________________', '______________________________', '_______________________________', '________________________________', '__________________________________', '___________________________________', '____________________________________', '_____________________________________', '______________________________________', '_______________________________________', '_________________________________________', '__________________________________________', '____________________________________________', '_____________________________________________', '______________________________________________', '________________________________________________', '_________________________________________________', '__________________________________________________', '___________________________________________________', '____________________________________________________', '_____________________________________________________', '______________________________________________________', '_______________________________________________________', '________________________________________________________', '_________________________________________________________', '__________________________________________________________', '___________________________________________________________', '____________________________________________________________', '_____________________________________________________________', '______________________________________________________________', '_______________________________________________________________', '________________________________________________________________', '_________________________________________________________________', '___________________________________________________________________', '____________________________________________________________________', '_____________________________________________________________________', '______________________________________________________________________', '_______________________________________________________________________', '________________________________________________________________________', '_________________________________________________________________________', '__________________________________________________________________________', '___________________________________________________________________________', '____________________________________________________________________________', '_____________________________________________________________________________', '______________________________________________________________________________', '_______________________________________________________________________________', '________________________________________________________________________________', '_________________________________________________________________________________', '______________________________________________________________x________', '_____________________________________________________________oooo___oooo__', '___________________________________________ooo__', '______________________________________cut', '________________________________state____________zip_____________', '______________________nnnnn______', '___________________the', '_________pratice', '_________utrecht_________________the', '_______ooo__', '______nnnnn______________________', '______victor', '_____u_____', '____i__i__', '____ovt', '___i__', '___i__ii', '___need', '___no', '___other', '___rp', '___samuel___', '___v_____', '___wreck__', '___yes', '__accept', '__behavior__', '__but', '__cgschot', '__dave', '__even', '__experience__', '__from_________________________________', '__gethostname', '__h', '__hr', '__ian', '__j', '__l__', '__l_l', '__leave', '__livian__', '__n_n_', '__not', '__o', '__oa', '__ohr', '__ooo________', '__ooo_____________', '__ooo______________________ooo__', '__p']
for item in new_stopwords:
    stopwords.append(item)

# %%
print(stopwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", '!', '"', '#', '$', '%', '&', "'", '(', ')', '*', '+', ',', '-', '.', '/', ':', ';', '<', '=', '>', '?', '@', '[', '\\', ']', '^', '_', '`', '{', '|', '}', '~', 'subject:', 'from:', 'date:', 'newsgroups:', 'message-id:', 'lines:', 'path:', 'organization:', 'would', 'writes:', 'references:', 'article', 'sender:', 'nntp-posting-host:', 'people', 'university', 'think', 'xref:', 'cantaloupe.srv.cs.cmu.edu', 'could', 'distribution:', 'first', 'anyone', 'world', 'really', 'since', 'right', 'believe', 'still']

# %%
Y = []
for i in range(len(data)):
    for doc in data[folders[i]]:
        Y.append(folders[i])

Y = np.array(Y)
Y
# Out:
# array(['alt.atheism', 'alt.atheism', 'alt.atheism', ...,
#        'talk.religion.misc', 'talk.religion.misc', 'talk.religion.misc'],
#       dtype='<U24')

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
from nltk.corpus import wordnet

# %%
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\acer\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
X = []
for folder in data:
    for doc in data[folder]:
        tokenized_doc = word_tokenize(doc)
        newdoc = []
        for word in tokenized_doc:
#             for c in word:
#                 if c.isdigit():
#                     words.append('0')
#                     break
#                 if c in stopwords:
#                     c =
#             word = lemmatizer.lemmatize(word)
            if any(c.isdigit() for c in word):
                 newdoc.append('0')
                 continue
            if word.lower() not in stopwords:
                newdoc.append(lemmatizer.lemmatize(word.lower()))
        X.append(newdoc)
X[0]
# Out:
# ['mathew',
#  'mathew',
#  'mantis.co.uk',
#  'subject',
#  'alt.atheism',
#  'faq',
#  'atheist',
#  'resource',
#  'summary',
#  'book',
#  'address',
#  'music',
#  '--',
#  'anything',
#  'related',
#  'atheism',
#  'keywords',
#  'faq',
#  'atheism',
#  'book',
#  'music',
#  'fiction',
#  'address',
#  'contact',
#  'expires',
#  'thu',
#  '0',
#  'apr',
#  '0',
#  '0',
#  'gmt',
#  'distribution',
#  'organization',
#  'mantis',
#  'consultant',
#  'cambridge',
#  'uk',
#  'supersedes',
#  '0',
#  'mantis.co.uk',
#  'line',
#  '0',
#  'archive-name',
#  'atheism/resources',
#  'alt-atheism-archive-name',
#  'resource',
#  'last-modified',
#  '0',
#  'december',
#  '0',
#  'version',
#  '0',
#  'atheist',
#  'resource',
#  'address',
#  'atheist',
#  'organization',
#  'usa',
#  'freedom',
#  'religion',
#  'foundation',
#  'darwin',
#  'fish',
#  'bumper',
#  'sticker',
#  'assorted',
#  'atheist',
#  'paraphernalia',
#  'available',
#  'freedom',
#  'religion',
#  'foundation',
#  'u',
#  'write',
#  'ffrf',
#  'p.o',
#  'box',
#  '0',
#  'madison',
#  'wi',
#  '0',
#  'telephone',
#  '0',
#  '0',
#  'evolution',
#  'design',
#  'evolution',
#  'design',
#  'sell',
#  '``',
#  'darwin',
#  'fish',
#  "''",
#  "'s",
#  'fish',
#  'symbol',
#  'like',
#  'one',
#  'christian',
#  'stick',
#  'car',
#  'foot',
#  'word',
#  '``',
#  'darwin',
#  "''",
#  'written',
#  'inside',
#  'deluxe',
#  'moulded',
#  '0',
#  'plastic',
#  'fish',
#  '0',
#  'postpaid',
#  'u',
#  'write',
#  'evolution',
#  'design',
#  '0',
#  'laurel',
#  'canyon',
#  '0',
#  'north',
#  'hollywood',
#  'ca',
#  '0',
#  'san',
#  'francisco',
#  'bay',
#  'area',
#  'get',
#  'darwin',
#  'fish',
#  'lynn',
#  'gold',
#  '--',
#  'try',
#  'mailing',
#  'figmo',
#  'netcom.com',
#  'net',
#  'go',
#  'lynn',
#  'directly',
#  'price',
#  '0',
#  'per',
#  'fish',
#  'american',
#  'atheist',
#  'press',
#  'aap',
#  'publish',
#  'various',
#  'atheist',
#  'book',
#  '--',
#  'critique',
#  'bible',
#  'list',
#  'biblical',
#  'contradiction',
#  'one',
#  'book',
#  "''",
#  'bible',
#  'handbook',
#  "''",
#  'w.p',
#  'ball',
#  'g.w',
#  'foote',
#  'american',
#  'atheist',
#  'press',
#  '0',
#  'pp',
#  'isbn',
#  '0',
#  '0',
#  'edition',
#  '0',
#  'bible',
#  'contradiction',
#  'absurdity',
#  'atrocity',
#  'immorality',
#  '...',
#  'contains',
#  'ball',
#  'foote',
#  '``',
#  'bible',
#  'contradicts',
#  "''",
#  'aap',
#  'based',
#  'king',
#  'james',
#  'version',
#  'bible',
#  'write',
#  'american',
#  'atheist',
#  'press',
#  'p.o',
#  'box',
#  '0',
#  'austin',
#  'tx',
#  '0',
#  '0',
#  'cameron',
#  'road',
#  'austin',
#  'tx',
#  '0',
#  'telephone',
#  '0',
#  '0',
#  'fax',
#  '0',
#  '0',
#  'prometheus',
#  'book',
#  'sell',
#  'book',
#  'including',
#  'haught',
#  "'s",
#  '``',
#  'holy',
#  'horror',
#  "''",
#  'see',
#  'write',
#  '0',
#  'east',
#  'amherst',
#  'street',
#  'buffalo',
#  'new',
#  'york',
#  '0',
#  'telephone',
#  '0',
#  '0',
#  'alternate',
#  'address',
#  'may',
#  'newer',
#  'older',
#  'prometheus',
#  'book',
#  '0',
#  'glenn',
#  'drive',
#  'buffalo',
#  'ny',
#  '0',
#  'african-american',
#  'humanism',
#  'organization',
#  'promoting',
#  'black',
#  'secular',
#  'humanism',
#  'uncovering',
#  'history',
#  'black',
#  'freethought',
#  'publish',
#  'quarterly',
#  'newsletter',
#  'aah',
#  'examiner',
#  'write',
#  'norm',
#  'r.',
#  'allen',
#  'jr.',
#  'african',
#  'american',
#  'humanism',
#  'p.o',
#  'box',
#  '0',
#  'buffalo',
#  'ny',
#  '0',
#  'united',
#  'kingdom',
#  'rationalist',
#  'press',
#  'association',
#  'national',
#  'secular',
#  'society',
#  '0',
#  'islington',
#  'high',
#  'street',
#  '0',
#  'holloway',
#  'road',
#  'london',
#  '0',
#  '0',
#  'london',
#  '0',
#  '0',
#  '0',
#  '0',
#  '0',
#  '0',
#  '0',
#  '0',
#  'british',
#  'humanist',
#  'association',
#  'south',
#  'place',
#  'ethical',
#  'society',
#  '0',
#  'lamb',
#  "'s",
#  'conduit',
#  'passage',
#  'conway',
#  'hall',
#  'london',
#  '0',
#  '0',
#  'red',
#  'lion',
#  'square',
#  '0',
#  '0',
#  '0',
#  'london',
#  '0',
#  '0',
#  'fax',
#  '0',
#  '0',
#  '0',
#  '0',
#  '0',
#  '0',
#  'national',
#  'secular',
#  'society',
#  'publish',
#  '``',
#  'freethinker',
#  "''",
#  'monthly',
#  'magazine',
#  'founded',
#  '0',
#  'germany',
#  'ibka',
#  'e.v',
#  'internationaler',
#  'bund',
#  'der',
#  'konfessionslosen',
#  'und',
#  'atheisten',
#  'postfach',
#  '0',
#  '0',
#  'berlin',
#  '0',
#  'germany',
#  'ibka',
#  'publish',
#  'journal',
#  'miz',
#  'materialien',
#  'und',
#  'informationen',
#  'zur',
#  'zeit',
#  'politisches',
#  'journal',
#  'der',
#  'konfessionslosesn',
#  'und',
#  'atheisten',
#  'hrsg',
#  'ibka',
#  'e.v',
#  'miz-vertrieb',
#  'postfach',
#  '0',
#  '0',
#  'berlin',
#  '0',
#  'germany',
#  'atheist',
#  'book',
#  'write',
#  'ibdk',
#  'internationaler',
#  'b',
#  "''",
#  'ucherdienst',
#  'der',
#  'konfessionslosen',
#  'postfach',
#  '0',
#  '0',
#  'hannover',
#  '0',
#  'germany',
#  'telephone',
#  '0',
#  'book',
#  '--',
#  'fiction',
#  'thomas',
#  'm.',
#  'disch',
#  "''",
#  'santa',
#  'claus',
#  'compromise',
#  "''",
#  'short',
#  'story',
#  'ultimate',
#  'proof',
#  'santa',
#  'exists',
#  'character',
#  'event',
#  'fictitious',
#  'similarity',
#  'living',
#  'dead',
#  'god',
#  '--',
#  'uh',
#  'well',
#  '...',
#  'walter',
#  'm.',
#  'miller',
#  'jr',
#  "''",
#  'canticle',
#  'leibowitz',
#  "''",
#  'one',
#  'gem',
#  'post',
#  'atomic',
#  'doomsday',
#  'novel',
#  'monk',
#  'spent',
#  'life',
#  'copying',
#  'blueprint',
#  '``',
#  'saint',
#  'leibowitz',
#  "''",
#  'filling',
#  'sheet',
#  'paper',
#  'ink',
#  'leaving',
#  'white',
#  'line',
#  'letter',
#  'edgar',
#  'pangborn',
#  "''",
#  'davy',
#  "''",
#  'post',
#  'atomic',
#  'doomsday',
#  'novel',
#  'set',
#  'clerical',
#  'state',
#  'church',
#  'example',
#  'forbids',
#  '``',
#  'produce',
#  'describe',
#  'use',
#  'substance',
#  'containing',
#  '...',
#  'atom',
#  "''",
#  'philip',
#  'k.',
#  'dick',
#  'philip',
#  'k.',
#  'dick',
#  'dick',
#  'wrote',
#  'many',
#  'philosophical',
#  'thought-provoking',
#  'short',
#  'story',
#  'novel',
#  'story',
#  'bizarre',
#  'time',
#  'approachable',
#  'wrote',
#  'mainly',
#  'sf',
#  'wrote',
#  'truth',
#  'religion',
#  'rather',
#  'technology',
#  'although',
#  'often',
#  'believed',
#  'met',
#  'sort',
#  'god',
#  'remained',
#  'sceptical',
#  'amongst',
#  'novel',
#  'following',
#  'relevance',
#  "''",
#  'galactic',
#  'pot-healer',
#  "''",
#  'fallible',
#  'alien',
#  'deity',
#  'summons',
#  'group',
#  'earth',
#  'craftsman',
#  'woman',
#  'remote',
#  'planet',
#  'raise',
#  'giant',
#  'cathedral',
#  'beneath',
#  'ocean',
#  'deity',
#  'begin',
#  'demand',
#  'faith',
#  'earthers',
#  'pot-healer',
#  'joe',
#  'fernwright',
#  'unable',
#  'comply',
#  'polished',
#  'ironic',
#  'amusing',
#  'novel',
#  '``',
#  'maze',
#  'death',
#  "''",
#  'noteworthy',
#  'description',
#  'technology-based',
#  'religion',
#  '``',
#  'vali',
#  "''",
#  'schizophrenic',
#  'hero',
#  'search',
#  'hidden',
#  'mystery',
#  'gnostic',
#  'christianity',
#  'reality',
#  'fired',
#  'brain',
#  'pink',
#  'laser',
#  'beam',
#  'unknown',
#  'possibly',
#  'divine',
#  'origin',
#  'accompanied',
#  'dogmatic',
#  'dismissively',
#  'atheist',
#  'friend',
#  'assorted',
#  'odd',
#  'character',
#  '``',
#  'divine',
#  'invasion',
#  "''",
#  'god',
#  'invades',
#  'earth',
#  'making',
#  'young',
#  'woman',
#  'pregnant',
#  'return',
#  'another',
#  'star',
#  'system',
#  'unfortunately',
#  'terminally',
#  'ill',
#  'must',
#  'assisted',
#  'dead',
#  'man',
#  'whose',
#  'brain',
#  'wired',
#  '0',
#  'easy',
#  'listening',
#  'music',
#  'margaret',
#  'atwood',
#  "''",
#  'handmaid',
#  "'s",
#  'tale',
#  "''",
#  'story',
#  'based',
#  'premise',
#  'u',
#  'congress',
#  'mysteriously',
#  'assassinated',
#  'fundamentalist',
#  'quickly',
#  'take',
#  'charge',
#  'nation',
#  'set',
#  "''",
#  "''",
#  'book',
#  'diary',
#  'woman',
#  "'s",
#  'life',
#  'try',
#  'live',
#  'new',
#  'christian',
#  'theocracy',
#  'woman',
#  "'s",
#  'property',
#  'revoked',
#  'bank',
#  'account',
#  'closed',
#  'sinful',
#  'luxury',
#  'outlawed',
#  'radio',
#  'used',
#  'reading',
#  'bible',
#  'crime',
#  'punished',
#  'retroactively',
#  'doctor',
#  'performed',
#  'legal',
#  'abortion',
#  '``',
#  'old',
#  "''",
#  'hunted',
#  'hanged',
#  'atwood',
#  "'s",
#  'writing',
#  'style',
#  'difficult',
#  'get',
#  'used',
#  'tale',
#  'grows',
#  'chilling',
#  'go',
#  'various',
#  'author',
#  "''",
#  'bible',
#  "''",
#  'somewhat',
#  'dull',
#  'rambling',
#  'work',
#  'often',
#  'criticized',
#  'however',
#  'probably',
#  'worth',
#  'reading',
#  "'ll",
#  'know',
#  'fuss',
#  'exists',
#  'many',
#  'different',
#  'version',
#  'make',
#  'sure',
#  'get',
#  'one',
#  'true',
#  'version',
#  'book',
#  '--',
#  'non-fiction',
#  'peter',
#  'de',
#  'rosa',
#  "''",
#  'vicar',
#  'christ',
#  "''",
#  'bantam',
#  'press',
#  '0',
#  'although',
#  'de',
#  'rosa',
#  'seems',
#  'christian',
#  'even',
#  'catholic',
#  'enlighting',
#  'history',
#  'papal',
#  'immorality',
#  'adultery',
#  'fallacy',
#  'etc',
#  'german',
#  'translation',
#  '``',
#  'gottes',
#  'erste',
#  'diener',
#  'die',
#  'dunkle',
#  'seite',
#  'de',
#  'papsttums',
#  "''",
#  'droemer-knaur',
#  '0',
#  'michael',
#  'martin',
#  "''",
#  'atheism',
#  'philosophical',
#  'justification',
#  "''",
#  'temple',
#  'press',
#  'philadelphia',
#  'usa',
#  'detailed',
#  'scholarly',
#  'justification',
#  'atheism',
#  'contains',
#  'outstanding',
#  'appendix',
#  'defining',
#  'terminology',
#  'usage',
#  'necessarily',
#  'tendentious',
#  'area',
#  'argues',
#  '``',
#  'negative',
#  'atheism',
#  "''",
#  'i.e',
#  '``',
#  'non-belief',
#  'existence',
#  'god',
#  "''",
#  'also',
#  '``',
#  'positive',
#  'atheism',
#  "''",
#  '``',
#  'belief',
#  'non-existence',
#  'god',
#  "''",
#  'includes',
#  'great',
#  'refutation',
#  'challenging',
#  'argument',
#  'god',
#  'particular',
#  'attention',
#  'paid',
#  'refuting',
#  'contempory',
#  'theist',
#  'platinga',
#  'swinburne',
#  '0',
#  'page',
#  'isbn',
#  '0',
#  'hardcover',
#  'paperback',
#  'also',
#  'available',
#  "''",
#  'case',
#  'christianity',
#  "''",
#  'temple',
#  'press',
#  'comprehensive',
#  'critique',
#  'christianity',
#  'considers',
#  'best',
#  'contemporary',
#  'defence',
#  'christianity',
#  'ultimately',
#  'demonstrates',
#  'unsupportable',
#  'and/or',
#  'incoherent',
#  '0',
#  'page',
#  'isbn',
#  '0',
#  'james',
#  'turner',
#  "''",
#  'without',
#  'god',
#  'without',
#  'creed',
#  "''",
#  'john',
#  'hopkins',
#  'press',
#  'baltimore',
#  'md',
#  'usa',
#  'subtitled',
#  '``',
#  'origin',
#  'unbelief',
#  'america',
#  "''",
#  'examines',
#  'way',
#  'unbelief',
#  'whether',
#  'agnostic',
#  'atheistic',
#  'became',
#  'mainstream',
#  'alternative',
#  'world-view',
#  'focus',
#  'period',
#  '0',
#  'considering',
#  'france',
#  'britain',
#  'emphasis',
#  'american',
#  'particularly',
#  'new',
#  'england',
#  'development',
#  '``',
#  'neither',
#  'religious',
#  'history',
#  'secularization',
#  'atheism',
#  'without',
#  'god',
#  'without',
#  'creed',
#  'rather',
#  'intellectual',
#  'history',
#  'fate',
#  'single',
#  'idea',
#  'belief',
#  'god',
#  'exists',
#  "''",
#  '0',
#  'page',
#  'isbn',
#  'hardcover',
#  '0',
#  'paper',
#  '0',
#  'george',
#  'seldes',
#  'editor',
#  "''",
#  'great',
#  'thought',
#  "''",
#  'ballantine',
#  'book',
#  'new',
#  'york',
#  'usa',
#  '``',
#  'dictionary',
#  'quotation',
#  "''",
#  'different',
#  'kind',
#  'concentrating',
#  'statement',
#  'writing',
#  'explicitly',
#  'implicitly',
#  'present',
#  'person',
#  "'s",
#  'philosophy',
#  'world-view',
#  'includes',
#  'obscure',
#  'often',
#  'suppressed',
#  'opinion',
#  'many',
#  'popular',
#  'observation',
#  'trace',
#  'way',
#  'various',
#  'expressed',
#  'twisted',
#  'idea',
#  'century',
#  'quite',
#  'number',
#  'quotation',
#  'derived',
#  'cardiff',
#  "'s",
#  '``',
#  'great',
#  'men',
#  'religion',
#  "''",
#  'noyes',
#  '``',
#  'view',
#  'religion',
#  "''",
#  '0',
#  'page',
#  'isbn',
#  'paper',
#  '0',
#  ...]

# %%
combineWord = []
for doc in X:
    merged = ' '.join(doc)
    combineWord.append(merged)
combineWord[0]
# Out:
# "mathew mathew mantis.co.uk subject alt.atheism faq atheist resource summary book address music -- anything related atheism keywords faq atheism book music fiction address contact expires thu 0 apr 0 0 gmt distribution organization mantis consultant cambridge uk supersedes 0 mantis.co.uk line 0 archive-name atheism/resources alt-atheism-archive-name resource last-modified 0 december 0 version 0 atheist resource address atheist organization usa freedom religion foundation darwin fish bumper sticker assorted atheist paraphernalia available freedom religion foundation u write ffrf p.o box 0 madison wi 0 telephone 0 0 evolution design evolution design sell `` darwin fish '' 's fish symbol like one christian stick car foot word `` darwin '' written inside deluxe moulded 0 plastic fish 0 postpaid u write evolution design 0 laurel canyon 0 north hollywood ca 0 san francisco bay area get darwin fish lynn gold -- try mailing figmo netcom.com net go lynn directly price 0 per fish american atheist press aap publish various atheist book -- critique bible list biblical contradiction one book '' bible handbook '' w.p ball g.w foote american atheist press 0 pp isbn 0 0 edition 0 bible contradiction absurdity atrocity immorality ... contains ball foote `` bible contradicts '' aap based king james version bible write american atheist press p.o box 0 austin tx 0 0 cameron road austin tx 0 telephone 0 0 fax 0 0 prometheus book sell book including haught 's `` holy horror '' see write 0 east amherst street buffalo new york 0 telephone 0 0 alternate address may newer older prometheus book 0 glenn drive buffalo ny 0 african-american humanism organization promoting black secular humanism uncovering history black freethought publish quarterly newsletter aah examiner write norm r. allen jr. african american humanism p.o box 0 buffalo ny 0 united kingdom rationalist press association national secular society 0 islington high street 0 holloway road london 0 0 london 0 0 0 0 0 0 0 0 british humanist association south place ethical society 0 lamb 's conduit passage conway hall london 0 0 red lion square 0 0 0 london 0 0 fax 0 0 0 0 0 0 national secular society publish `` freethinker '' monthly magazine founded 0 germany ibka e.v internationaler bund der konfessionslosen und atheisten postfach 0 0 berlin 0 germany ibka publish journal miz materialien und informationen zur zeit politisches journal der konfessionslosesn und atheisten hrsg ibka e.v miz-vertrieb postfach 0 0 berlin 0 germany atheist book write ibdk internationaler b '' ucherdienst der konfessionslosen postfach 0 0 hannover 0 germany telephone 0 book -- fiction thomas m. disch '' santa claus compromise '' short story ultimate proof santa exists character event fictitious similarity living dead god -- uh well ... walter m. miller jr '' canticle leibowitz '' one gem post atomic doomsday novel monk spent life copying blueprint `` saint leibowitz '' filling sheet paper ink leaving white line letter edgar pangborn '' davy '' post atomic doomsday novel set clerical state church example forbids `` produce describe use substance containing ... atom '' philip k. dick philip k. dick dick wrote many philosophical thought-provoking short story novel story bizarre time approachable wrote mainly sf wrote truth religion rather technology although often believed met sort god remained sceptical amongst novel following relevance '' galactic pot-healer '' fallible alien deity summons group earth craftsman woman remote planet raise giant cathedral beneath ocean deity begin demand faith earthers pot-healer joe fernwright unable comply polished ironic amusing novel `` maze death '' noteworthy description technology-based religion `` vali '' schizophrenic hero search hidden mystery gnostic christianity reality fired brain pink laser beam unknown possibly divine origin accompanied dogmatic dismissively atheist friend assorted odd character `` divine invasion '' god invades earth making young woman pregnant return anot ...
